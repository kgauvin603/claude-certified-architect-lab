# %% [markdown]
# # Batch Extraction
# Iterate over inbound documents and collect structured outputs.

# %%
from pathlib import Path
files = list(Path('../data/inbound').glob('*'))
files

# %%
# Example placeholder
# from src.agent.extraction import extract_invoice_text
# for file in files:
#     text = file.read_text()
#     print(extract_invoice_text(text))
