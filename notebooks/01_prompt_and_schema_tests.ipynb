# %% [markdown]
# # Prompt and Schema Tests
# Use this notebook to compare extraction prompts and validate JSON output against Pydantic schemas.

# %%
from src.agent.schemas import ExtractedInvoice
from pydantic import ValidationError

# %%
sample = {
    'invoice_number': 'INV-100',
    'vendor_name': 'ACME',
    'currency': 'USD',
    'amount_due': 42.5,
}
ExtractedInvoice.model_validate(sample)
